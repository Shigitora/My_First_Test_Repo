# %% [markdown]
# <a href="https://colab.research.google.com/github/Shigitora/My_First_Test_Repo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования MARKDOWN

# %% [markdown]
# *   Расихин Максим
# *   Черненко Михаил

# %% [markdown]
# ![изображение_2022-04-10_212724492.png](data:image/png;base64,...)

# %% [markdown]
# [Ссылка на руководство по Markdown](https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=5fCEDCU_qrC0)
